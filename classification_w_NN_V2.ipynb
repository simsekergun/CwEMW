# %% [markdown]
# <a href="https://colab.research.google.com/github/simsekergun/CwEMW/blob/main/classification_w_NN_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import every module we will or we might need
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from google.colab import files
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Model
from keras.layers import Input
from keras.layers import Dropout
from keras.layers import concatenate
from keras import optimizers
from keras import backend
from keras.layers import LeakyReLU, PReLU
from keras.metrics import categorical_accuracy

# %%
# X data was large, so it was divided into 60 pieces
# call this function to get both X and y
def get_CwEMW_data():
  y = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/Y.csv',header=None)
  X01 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW01.csv',header=None)
  X02 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW02.csv',header=None)
  X03 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW03.csv',header=None)
  X04 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW04.csv',header=None)
  X05 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW05.csv',header=None)
  X06 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW06.csv',header=None)
  X07 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW07.csv',header=None)
  X08 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW08.csv',header=None)
  X09 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW09.csv',header=None)
  X10 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW10.csv',header=None)
  X11 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW11.csv',header=None)
  X12 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW12.csv',header=None)
  X13 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW13.csv',header=None)
  X14 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW14.csv',header=None)
  X15 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW15.csv',header=None)
  X16 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW16.csv',header=None)
  X17 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW17.csv',header=None)
  X18 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW18.csv',header=None)
  X19 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW19.csv',header=None)
  X20 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW20.csv',header=None)
  X21 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW21.csv',header=None)
  X22 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW22.csv',header=None)
  X23 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW23.csv',header=None)
  X24 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW24.csv',header=None)
  X25 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW25.csv',header=None)
  X26 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW26.csv',header=None)
  X27 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW27.csv',header=None)
  X28 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW28.csv',header=None)
  X29 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW29.csv',header=None)
  X30 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW30.csv',header=None)
  X31 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW31.csv',header=None)
  X32 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW32.csv',header=None)
  X33 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW33.csv',header=None)
  X34 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW34.csv',header=None)
  X35 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW35.csv',header=None)
  X36 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW36.csv',header=None)
  X37 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW37.csv',header=None)
  X38 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW38.csv',header=None)
  X39 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW39.csv',header=None)
  X40 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW40.csv',header=None)
  X41 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW41.csv',header=None)
  X42 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW42.csv',header=None)
  X43 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW43.csv',header=None)
  X44 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW44.csv',header=None)
  X45 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW45.csv',header=None)
  X46 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW46.csv',header=None)
  X47 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW47.csv',header=None)
  X48 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW48.csv',header=None)
  X49 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW49.csv',header=None)
  X50 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW50.csv',header=None)
  X51 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW51.csv',header=None)
  X52 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW52.csv',header=None)
  X53 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW53.csv',header=None)
  X54 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW54.csv',header=None)
  X55 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW55.csv',header=None)
  X56 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW56.csv',header=None)
  X57 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW57.csv',header=None)
  X58 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW58.csv',header=None)
  X59 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW59.csv',header=None)
  X60 = pd.read_csv('https://raw.githubusercontent.com/simsekergun/CwEMW/main/datasets/CeEMW60.csv',header=None)

  X0 = pd.concat([X01.iloc[1:,1:], X02.iloc[1:,1:], X03.iloc[1:,1:], X04.iloc[1:,1:], X05.iloc[1:,1:], X06.iloc[1:,1:], X07.iloc[1:,1:], X08.iloc[1:,1:], X09.iloc[1:,1:], X10.iloc[1:,1:],
                  X11.iloc[1:,1:], X12.iloc[1:,1:], X13.iloc[1:,1:], X14.iloc[1:,1:], X15.iloc[1:,1:], X16.iloc[1:,1:], X17.iloc[1:,1:], X18.iloc[1:,1:], X19.iloc[1:,1:], X20.iloc[1:,1:],
                  X21.iloc[1:,1:], X22.iloc[1:,1:], X23.iloc[1:,1:], X24.iloc[1:,1:], X25.iloc[1:,1:], X26.iloc[1:,1:], X27.iloc[1:,1:], X28.iloc[1:,1:], X29.iloc[1:,1:], X30.iloc[1:,1:],
                  X31.iloc[1:,1:], X32.iloc[1:,1:], X33.iloc[1:,1:], X34.iloc[1:,1:], X35.iloc[1:,1:], X36.iloc[1:,1:], X37.iloc[1:,1:], X38.iloc[1:,1:], X39.iloc[1:,1:], X40.iloc[1:,1:],
                  X41.iloc[1:,1:], X42.iloc[1:,1:], X43.iloc[1:,1:], X44.iloc[1:,1:], X45.iloc[1:,1:], X46.iloc[1:,1:], X47.iloc[1:,1:], X48.iloc[1:,1:], X49.iloc[1:,1:], X50.iloc[1:,1:],
                  X51.iloc[1:,1:], X52.iloc[1:,1:], X53.iloc[1:,1:], X54.iloc[1:,1:], X55.iloc[1:,1:], X56.iloc[1:,1:], X57.iloc[1:,1:], X58.iloc[1:,1:], X59.iloc[1:,1:], X60.iloc[1:,1:]])

  return X0, y

# %%
X, y = get_CwEMW_data()

# %%
# Let's convert numbers to categoricals
y = to_categorical(y, num_classes=10)

# %%
X = (X-X.mean())/(X.std())

# %%
X.head(3)
# Out:
#         1         2         3         4         5         6         7    \
# 1  0.304425  0.543136  0.726137  0.866364  0.967259  1.023752  1.023028
# 2  0.710653  0.954424  1.148344  1.306243  1.430303  1.512793  1.536270
# 3  1.259712  1.033179  0.788347  0.518403  0.213687 -0.133909 -0.525781
#
#         8         9         10   ...       615       616       617       618  \
# 1  0.946970  0.780322  0.525813  ...  0.634303  0.412217  0.154805 -0.096327
# 2  1.475191  1.304604  1.019306  ... -0.849030 -0.813777 -0.707787 -0.530532
# 3 -0.947887 -1.360755 -1.700758  ... -0.545552 -0.690551 -0.880950 -1.081399
#
#         619       620       621       622       623       624
# 1 -0.295370 -0.413487 -0.443739 -0.392688 -0.271982 -0.094586
# 2 -0.306702 -0.072046  0.143439  0.320754  0.449152  0.522562
# 3 -1.252648 -1.369005 -1.421193 -1.409209 -1.336142 -1.205935
#
# [3 rows x 624 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, random_state=42,stratify=y)

# %%
# let's check the shapes
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((30000, 624), (30000, 624), (30000, 10), (30000, 10))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Activation
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from keras.regularizers import l1_l2
from keras.initializers import HeNormal

initializer = HeNormal()

model = Sequential()
model.add(Dense(500, input_dim=624, kernel_initializer=initializer,activation='relu'))
model.add(Dense(250, kernel_initializer=initializer,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(100, kernel_initializer=initializer,activation='relu'))
model.add(Dense(30, kernel_initializer=initializer,activation='relu'))
model.add(BatchNormalization())
model.add(Dense(10, activation='softmax'))

opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['categorical_accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='val_categorical_accuracy', factor=0.8, patience=2,verbose=2)
early_stop = EarlyStopping(monitor='val_categorical_accuracy',verbose=2,mode='max',patience=5)
check_point = ModelCheckpoint('best_model.h5', monitor= "val_categorical_accuracy",verbose=2,save_best_only=True,mode='max')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 500)               312500
#
#  dense_1 (Dense)             (None, 250)               125250
#
#  dropout (Dropout)           (None, 250)               0
#
#  dense_2 (Dense)             (None, 100)               25100
#
#  dense_3 (Dense)             (None, 30)                3030
#
#  batch_normalization (Batch  (None, 30)                120
#  Normalization)
#
#  dense_4 (Dense)             (None, 10)                310
#
# =================================================================
# Total params: 466310 (1.78 MB)
# Trainable params: 466250 (1.78 MB)
# Non-trainable params: 60 (240.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    verbose=1,
    validation_data=(X_test, y_test),callbacks=[reduce_lr,early_stop,check_point])
# Out:
# Epoch 1/100
# 929/938 [============================>.] - ETA: 0s - loss: 1.6689 - categorical_accuracy: 0.4238
# Epoch 1: val_categorical_accuracy improved from -inf to 0.62727, saving model to best_model.h5
# 938/938 [==============================] - 14s 7ms/step - loss: 1.6644 - categorical_accuracy: 0.4257 - val_loss: 1.1095 - val_categorical_accuracy: 0.6273 - lr: 0.0010
# Epoch 2/100
#  27/938 [..............................] - ETA: 3s - loss: 1.2700 - categorical_accuracy: 0.5775
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 934/938 [============================>.] - ETA: 0s - loss: 1.1216 - categorical_accuracy: 0.6231
# Epoch 2: val_categorical_accuracy improved from 0.62727 to 0.71413, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 1.1210 - categorical_accuracy: 0.6233 - val_loss: 0.8605 - val_categorical_accuracy: 0.7141 - lr: 0.0010
# Epoch 3/100
# 938/938 [==============================] - ETA: 0s - loss: 0.9417 - categorical_accuracy: 0.6842
# Epoch 3: val_categorical_accuracy improved from 0.71413 to 0.75070, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.9417 - categorical_accuracy: 0.6842 - val_loss: 0.7594 - val_categorical_accuracy: 0.7507 - lr: 0.0010
# Epoch 4/100
# 931/938 [============================>.] - ETA: 0s - loss: 0.8423 - categorical_accuracy: 0.7209
# Epoch 4: val_categorical_accuracy improved from 0.75070 to 0.78070, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.8428 - categorical_accuracy: 0.7207 - val_loss: 0.6789 - val_categorical_accuracy: 0.7807 - lr: 0.0010
# Epoch 5/100
# 936/938 [============================>.] - ETA: 0s - loss: 0.7799 - categorical_accuracy: 0.7429
# Epoch 5: val_categorical_accuracy improved from 0.78070 to 0.78120, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.7799 - categorical_accuracy: 0.7429 - val_loss: 0.6691 - val_categorical_accuracy: 0.7812 - lr: 0.0010
# Epoch 6/100
# 935/938 [============================>.] - ETA: 0s - loss: 0.7304 - categorical_accuracy: 0.7618
# Epoch 6: val_categorical_accuracy improved from 0.78120 to 0.79203, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.7301 - categorical_accuracy: 0.7619 - val_loss: 0.6341 - val_categorical_accuracy: 0.7920 - lr: 0.0010
# Epoch 7/100
# 936/938 [============================>.] - ETA: 0s - loss: 0.7026 - categorical_accuracy: 0.7695
# Epoch 7: val_categorical_accuracy improved from 0.79203 to 0.80473, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.7025 - categorical_accuracy: 0.7695 - val_loss: 0.6030 - val_categorical_accuracy: 0.8047 - lr: 0.0010
# Epoch 8/100
# 930/938 [============================>.] - ETA: 0s - loss: 0.6666 - categorical_accuracy: 0.7818
# Epoch 8: val_categorical_accuracy improved from 0.80473 to 0.81713, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.6667 - categorical_accuracy: 0.7817 - val_loss: 0.5555 - val_categorical_accuracy: 0.8171 - lr: 0.0010
# Epoch 9/100
# 927/938 [============================>.] - ETA: 0s - loss: 0.6305 - categorical_accuracy: 0.7944
# Epoch 9: val_categorical_accuracy improved from 0.81713 to 0.82067, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.6312 - categorical_accuracy: 0.7940 - val_loss: 0.5499 - val_categorical_accuracy: 0.8207 - lr: 0.0010
# Epoch 10/100
# 930/938 [============================>.] - ETA: 0s - loss: 0.6099 - categorical_accuracy: 0.7994
# Epoch 10: val_categorical_accuracy did not improve from 0.82067
# 938/938 [==============================] - 6s 6ms/step - loss: 0.6102 - categorical_accuracy: 0.7993 - val_loss: 0.5443 - val_categorical_accuracy: 0.8204 - lr: 0.0010
# Epoch 11/100
# 938/938 [==============================] - ETA: 0s - loss: 0.5949 - categorical_accuracy: 0.8056
# Epoch 11: val_categorical_accuracy improved from 0.82067 to 0.82620, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.5949 - categorical_accuracy: 0.8056 - val_loss: 0.5274 - val_categorical_accuracy: 0.8262 - lr: 0.0010
# Epoch 12/100
# 926/938 [============================>.] - ETA: 0s - loss: 0.5740 - categorical_accuracy: 0.8107
# Epoch 12: val_categorical_accuracy improved from 0.82620 to 0.83853, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.5756 - categorical_accuracy: 0.8099 - val_loss: 0.5013 - val_categorical_accuracy: 0.8385 - lr: 0.0010
# Epoch 13/100
# 938/938 [==============================] - ETA: 0s - loss: 0.5527 - categorical_accuracy: 0.8178
# Epoch 13: val_categorical_accuracy did not improve from 0.83853
# 938/938 [==============================] - 6s 6ms/step - loss: 0.5527 - categorical_accuracy: 0.8178 - val_loss: 0.5021 - val_categorical_accuracy: 0.8344 - lr: 0.0010
# Epoch 14/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.5367 - categorical_accuracy: 0.8253
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
#
# Epoch 14: val_categorical_accuracy did not improve from 0.83853
# 938/938 [==============================] - 6s 6ms/step - loss: 0.5366 - categorical_accuracy: 0.8253 - val_loss: 0.4953 - val_categorical_accuracy: 0.8364 - lr: 0.0010
# Epoch 15/100
# 932/938 [============================>.] - ETA: 0s - loss: 0.4932 - categorical_accuracy: 0.8383
# Epoch 15: val_categorical_accuracy improved from 0.83853 to 0.84977, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.4932 - categorical_accuracy: 0.8383 - val_loss: 0.4584 - val_categorical_accuracy: 0.8498 - lr: 8.0000e-04
# Epoch 16/100
# 934/938 [============================>.] - ETA: 0s - loss: 0.4852 - categorical_accuracy: 0.8401
# Epoch 16: val_categorical_accuracy improved from 0.84977 to 0.85450, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.4848 - categorical_accuracy: 0.8402 - val_loss: 0.4453 - val_categorical_accuracy: 0.8545 - lr: 8.0000e-04
# Epoch 17/100
# 934/938 [============================>.] - ETA: 0s - loss: 0.4732 - categorical_accuracy: 0.8423
# Epoch 17: val_categorical_accuracy did not improve from 0.85450
# 938/938 [==============================] - 6s 6ms/step - loss: 0.4727 - categorical_accuracy: 0.8426 - val_loss: 0.4673 - val_categorical_accuracy: 0.8470 - lr: 8.0000e-04
# Epoch 18/100
# 927/938 [============================>.] - ETA: 0s - loss: 0.4603 - categorical_accuracy: 0.8482
# Epoch 18: val_categorical_accuracy improved from 0.85450 to 0.85570, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.4607 - categorical_accuracy: 0.8483 - val_loss: 0.4435 - val_categorical_accuracy: 0.8557 - lr: 8.0000e-04
# Epoch 19/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.4500 - categorical_accuracy: 0.8488
# Epoch 19: val_categorical_accuracy improved from 0.85570 to 0.86113, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.4500 - categorical_accuracy: 0.8488 - val_loss: 0.4244 - val_categorical_accuracy: 0.8611 - lr: 8.0000e-04
# Epoch 20/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.4386 - categorical_accuracy: 0.8562
# Epoch 20: val_categorical_accuracy improved from 0.86113 to 0.86450, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.4386 - categorical_accuracy: 0.8562 - val_loss: 0.4164 - val_categorical_accuracy: 0.8645 - lr: 8.0000e-04
# Epoch 21/100
# 927/938 [============================>.] - ETA: 0s - loss: 0.4409 - categorical_accuracy: 0.8556
# Epoch 21: val_categorical_accuracy improved from 0.86450 to 0.86457, saving model to best_model.h5
# 938/938 [==============================] - 6s 7ms/step - loss: 0.4407 - categorical_accuracy: 0.8557 - val_loss: 0.4115 - val_categorical_accuracy: 0.8646 - lr: 8.0000e-04
# Epoch 22/100
# 938/938 [==============================] - ETA: 0s - loss: 0.4226 - categorical_accuracy: 0.8609
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
#
# Epoch 22: val_categorical_accuracy did not improve from 0.86457
# 938/938 [==============================] - 6s 6ms/step - loss: 0.4226 - categorical_accuracy: 0.8609 - val_loss: 0.4336 - val_categorical_accuracy: 0.8598 - lr: 8.0000e-04
# Epoch 23/100
# 930/938 [============================>.] - ETA: 0s - loss: 0.3849 - categorical_accuracy: 0.8731
# Epoch 23: val_categorical_accuracy improved from 0.86457 to 0.86713, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3851 - categorical_accuracy: 0.8730 - val_loss: 0.4074 - val_categorical_accuracy: 0.8671 - lr: 6.4000e-04
# Epoch 24/100
# 933/938 [============================>.] - ETA: 0s - loss: 0.3863 - categorical_accuracy: 0.8717
# Epoch 24: val_categorical_accuracy improved from 0.86713 to 0.86760, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3859 - categorical_accuracy: 0.8718 - val_loss: 0.4199 - val_categorical_accuracy: 0.8676 - lr: 6.4000e-04
# Epoch 25/100
# 938/938 [==============================] - ETA: 0s - loss: 0.3809 - categorical_accuracy: 0.8758
# Epoch 25: val_categorical_accuracy improved from 0.86760 to 0.86847, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3809 - categorical_accuracy: 0.8758 - val_loss: 0.4039 - val_categorical_accuracy: 0.8685 - lr: 6.4000e-04
# Epoch 26/100
# 935/938 [============================>.] - ETA: 0s - loss: 0.3721 - categorical_accuracy: 0.8754
# Epoch 26: val_categorical_accuracy improved from 0.86847 to 0.87533, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3723 - categorical_accuracy: 0.8753 - val_loss: 0.3842 - val_categorical_accuracy: 0.8753 - lr: 6.4000e-04
# Epoch 27/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.3671 - categorical_accuracy: 0.8809
# Epoch 27: val_categorical_accuracy did not improve from 0.87533
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3671 - categorical_accuracy: 0.8808 - val_loss: 0.3888 - val_categorical_accuracy: 0.8750 - lr: 6.4000e-04
# Epoch 28/100
# 930/938 [============================>.] - ETA: 0s - loss: 0.3650 - categorical_accuracy: 0.8794
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
#
# Epoch 28: val_categorical_accuracy did not improve from 0.87533
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3645 - categorical_accuracy: 0.8797 - val_loss: 0.3899 - val_categorical_accuracy: 0.8728 - lr: 6.4000e-04
# Epoch 29/100
# 927/938 [============================>.] - ETA: 0s - loss: 0.3346 - categorical_accuracy: 0.8894
# Epoch 29: val_categorical_accuracy improved from 0.87533 to 0.87953, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3349 - categorical_accuracy: 0.8895 - val_loss: 0.3728 - val_categorical_accuracy: 0.8795 - lr: 5.1200e-04
# Epoch 30/100
# 930/938 [============================>.] - ETA: 0s - loss: 0.3321 - categorical_accuracy: 0.8904
# Epoch 30: val_categorical_accuracy improved from 0.87953 to 0.87963, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3319 - categorical_accuracy: 0.8905 - val_loss: 0.3729 - val_categorical_accuracy: 0.8796 - lr: 5.1200e-04
# Epoch 31/100
# 936/938 [============================>.] - ETA: 0s - loss: 0.3288 - categorical_accuracy: 0.8924
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
#
# Epoch 31: val_categorical_accuracy did not improve from 0.87963
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3289 - categorical_accuracy: 0.8923 - val_loss: 0.3726 - val_categorical_accuracy: 0.8796 - lr: 5.1200e-04
# Epoch 32/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.3079 - categorical_accuracy: 0.8965
# Epoch 32: val_categorical_accuracy improved from 0.87963 to 0.88580, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.3079 - categorical_accuracy: 0.8965 - val_loss: 0.3546 - val_categorical_accuracy: 0.8858 - lr: 4.0960e-04
# Epoch 33/100
# 926/938 [============================>.] - ETA: 0s - loss: 0.2976 - categorical_accuracy: 0.9032
# Epoch 33: val_categorical_accuracy did not improve from 0.88580
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2974 - categorical_accuracy: 0.9032 - val_loss: 0.3637 - val_categorical_accuracy: 0.8830 - lr: 4.0960e-04
# Epoch 34/100
# 933/938 [============================>.] - ETA: 0s - loss: 0.2958 - categorical_accuracy: 0.8994
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
#
# Epoch 34: val_categorical_accuracy did not improve from 0.88580
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2959 - categorical_accuracy: 0.8994 - val_loss: 0.3677 - val_categorical_accuracy: 0.8833 - lr: 4.0960e-04
# Epoch 35/100
# 928/938 [============================>.] - ETA: 0s - loss: 0.2780 - categorical_accuracy: 0.9073
# Epoch 35: val_categorical_accuracy improved from 0.88580 to 0.88957, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2778 - categorical_accuracy: 0.9074 - val_loss: 0.3461 - val_categorical_accuracy: 0.8896 - lr: 3.2768e-04
# Epoch 36/100
# 934/938 [============================>.] - ETA: 0s - loss: 0.2693 - categorical_accuracy: 0.9101
# Epoch 36: val_categorical_accuracy did not improve from 0.88957
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2694 - categorical_accuracy: 0.9101 - val_loss: 0.3578 - val_categorical_accuracy: 0.8853 - lr: 3.2768e-04
# Epoch 37/100
# 936/938 [============================>.] - ETA: 0s - loss: 0.2628 - categorical_accuracy: 0.9136
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
#
# Epoch 37: val_categorical_accuracy did not improve from 0.88957
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2627 - categorical_accuracy: 0.9136 - val_loss: 0.3522 - val_categorical_accuracy: 0.8890 - lr: 3.2768e-04
# Epoch 38/100
# 935/938 [============================>.] - ETA: 0s - loss: 0.2514 - categorical_accuracy: 0.9168
# Epoch 38: val_categorical_accuracy improved from 0.88957 to 0.88990, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2514 - categorical_accuracy: 0.9168 - val_loss: 0.3518 - val_categorical_accuracy: 0.8899 - lr: 2.6214e-04
# Epoch 39/100
# 930/938 [============================>.] - ETA: 0s - loss: 0.2472 - categorical_accuracy: 0.9170
# Epoch 39: val_categorical_accuracy improved from 0.88990 to 0.89197, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2470 - categorical_accuracy: 0.9172 - val_loss: 0.3472 - val_categorical_accuracy: 0.8920 - lr: 2.6214e-04
# Epoch 40/100
# 935/938 [============================>.] - ETA: 0s - loss: 0.2473 - categorical_accuracy: 0.9150
# Epoch 40: val_categorical_accuracy did not improve from 0.89197
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2474 - categorical_accuracy: 0.9149 - val_loss: 0.3459 - val_categorical_accuracy: 0.8913 - lr: 2.6214e-04
# Epoch 41/100
# 929/938 [============================>.] - ETA: 0s - loss: 0.2394 - categorical_accuracy: 0.9193
# Epoch 41: val_categorical_accuracy improved from 0.89197 to 0.89220, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2392 - categorical_accuracy: 0.9193 - val_loss: 0.3476 - val_categorical_accuracy: 0.8922 - lr: 2.6214e-04
# Epoch 42/100
# 934/938 [============================>.] - ETA: 0s - loss: 0.2373 - categorical_accuracy: 0.9191
# Epoch 42: val_categorical_accuracy did not improve from 0.89220
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2376 - categorical_accuracy: 0.9191 - val_loss: 0.3496 - val_categorical_accuracy: 0.8906 - lr: 2.6214e-04
# Epoch 43/100
# 932/938 [============================>.] - ETA: 0s - loss: 0.2418 - categorical_accuracy: 0.9197
# Epoch 43: val_categorical_accuracy improved from 0.89220 to 0.89447, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2418 - categorical_accuracy: 0.9196 - val_loss: 0.3451 - val_categorical_accuracy: 0.8945 - lr: 2.6214e-04
# Epoch 44/100
# 927/938 [============================>.] - ETA: 0s - loss: 0.2287 - categorical_accuracy: 0.9229
# Epoch 44: val_categorical_accuracy did not improve from 0.89447
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2289 - categorical_accuracy: 0.9227 - val_loss: 0.3415 - val_categorical_accuracy: 0.8939 - lr: 2.6214e-04
# Epoch 45/100
# 928/938 [============================>.] - ETA: 0s - loss: 0.2274 - categorical_accuracy: 0.9233
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
#
# Epoch 45: val_categorical_accuracy did not improve from 0.89447
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2275 - categorical_accuracy: 0.9231 - val_loss: 0.3452 - val_categorical_accuracy: 0.8934 - lr: 2.6214e-04
# Epoch 46/100
# 932/938 [============================>.] - ETA: 0s - loss: 0.2183 - categorical_accuracy: 0.9261
# Epoch 46: val_categorical_accuracy improved from 0.89447 to 0.89530, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2186 - categorical_accuracy: 0.9260 - val_loss: 0.3409 - val_categorical_accuracy: 0.8953 - lr: 2.0972e-04
# Epoch 47/100
# 928/938 [============================>.] - ETA: 0s - loss: 0.2152 - categorical_accuracy: 0.9273
# Epoch 47: val_categorical_accuracy did not improve from 0.89530
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2151 - categorical_accuracy: 0.9273 - val_loss: 0.3549 - val_categorical_accuracy: 0.8919 - lr: 2.0972e-04
# Epoch 48/100
# 931/938 [============================>.] - ETA: 0s - loss: 0.2165 - categorical_accuracy: 0.9274
# Epoch 48: val_categorical_accuracy improved from 0.89530 to 0.89753, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2163 - categorical_accuracy: 0.9274 - val_loss: 0.3393 - val_categorical_accuracy: 0.8975 - lr: 2.0972e-04
# Epoch 49/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.2103 - categorical_accuracy: 0.9292
# Epoch 49: val_categorical_accuracy did not improve from 0.89753
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2103 - categorical_accuracy: 0.9292 - val_loss: 0.3419 - val_categorical_accuracy: 0.8961 - lr: 2.0972e-04
# Epoch 50/100
# 936/938 [============================>.] - ETA: 0s - loss: 0.2048 - categorical_accuracy: 0.9306
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
#
# Epoch 50: val_categorical_accuracy did not improve from 0.89753
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2047 - categorical_accuracy: 0.9306 - val_loss: 0.3433 - val_categorical_accuracy: 0.8953 - lr: 2.0972e-04
# Epoch 51/100
# 931/938 [============================>.] - ETA: 0s - loss: 0.1972 - categorical_accuracy: 0.9323
# Epoch 51: val_categorical_accuracy improved from 0.89753 to 0.89943, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1974 - categorical_accuracy: 0.9323 - val_loss: 0.3372 - val_categorical_accuracy: 0.8994 - lr: 1.6777e-04
# Epoch 52/100
# 931/938 [============================>.] - ETA: 0s - loss: 0.1960 - categorical_accuracy: 0.9337
# Epoch 52: val_categorical_accuracy did not improve from 0.89943
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1961 - categorical_accuracy: 0.9337 - val_loss: 0.3462 - val_categorical_accuracy: 0.8970 - lr: 1.6777e-04
# Epoch 53/100
# 932/938 [============================>.] - ETA: 0s - loss: 0.1946 - categorical_accuracy: 0.9330
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
#
# Epoch 53: val_categorical_accuracy did not improve from 0.89943
# 938/938 [==============================] - 6s 7ms/step - loss: 0.1946 - categorical_accuracy: 0.9330 - val_loss: 0.3436 - val_categorical_accuracy: 0.8981 - lr: 1.6777e-04
# Epoch 54/100
# 932/938 [============================>.] - ETA: 0s - loss: 0.1853 - categorical_accuracy: 0.9377
# Epoch 54: val_categorical_accuracy did not improve from 0.89943
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1851 - categorical_accuracy: 0.9377 - val_loss: 0.3472 - val_categorical_accuracy: 0.8983 - lr: 1.3422e-04
# Epoch 55/100
# 938/938 [==============================] - ETA: 0s - loss: 0.1815 - categorical_accuracy: 0.9371
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
#
# Epoch 55: val_categorical_accuracy did not improve from 0.89943
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1815 - categorical_accuracy: 0.9371 - val_loss: 0.3445 - val_categorical_accuracy: 0.8990 - lr: 1.3422e-04
# Epoch 56/100
# 928/938 [============================>.] - ETA: 0s - loss: 0.1773 - categorical_accuracy: 0.9398
# Epoch 56: val_categorical_accuracy improved from 0.89943 to 0.90057, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1767 - categorical_accuracy: 0.9400 - val_loss: 0.3417 - val_categorical_accuracy: 0.9006 - lr: 1.0737e-04
# Epoch 57/100
# 929/938 [============================>.] - ETA: 0s - loss: 0.1710 - categorical_accuracy: 0.9420
# Epoch 57: val_categorical_accuracy did not improve from 0.90057
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1705 - categorical_accuracy: 0.9423 - val_loss: 0.3454 - val_categorical_accuracy: 0.8987 - lr: 1.0737e-04
# Epoch 58/100
# 932/938 [============================>.] - ETA: 0s - loss: 0.1723 - categorical_accuracy: 0.9419
# Epoch 58: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
#
# Epoch 58: val_categorical_accuracy did not improve from 0.90057
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1723 - categorical_accuracy: 0.9419 - val_loss: 0.3453 - val_categorical_accuracy: 0.8995 - lr: 1.0737e-04
# Epoch 59/100
# 929/938 [============================>.] - ETA: 0s - loss: 0.1718 - categorical_accuracy: 0.9416
# Epoch 59: val_categorical_accuracy did not improve from 0.90057
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1714 - categorical_accuracy: 0.9418 - val_loss: 0.3429 - val_categorical_accuracy: 0.9000 - lr: 8.5899e-05
# Epoch 60/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.1632 - categorical_accuracy: 0.9451
# Epoch 60: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
#
# Epoch 60: val_categorical_accuracy did not improve from 0.90057
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1632 - categorical_accuracy: 0.9451 - val_loss: 0.3461 - val_categorical_accuracy: 0.8996 - lr: 8.5899e-05
# Epoch 61/100
# 930/938 [============================>.] - ETA: 0s - loss: 0.1606 - categorical_accuracy: 0.9451
# Epoch 61: val_categorical_accuracy improved from 0.90057 to 0.90067, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1607 - categorical_accuracy: 0.9451 - val_loss: 0.3432 - val_categorical_accuracy: 0.9007 - lr: 6.8719e-05
# Epoch 62/100
# 929/938 [============================>.] - ETA: 0s - loss: 0.1566 - categorical_accuracy: 0.9461
# Epoch 62: val_categorical_accuracy improved from 0.90067 to 0.90097, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1564 - categorical_accuracy: 0.9463 - val_loss: 0.3443 - val_categorical_accuracy: 0.9010 - lr: 6.8719e-05
# Epoch 63/100
# 938/938 [==============================] - ETA: 0s - loss: 0.1573 - categorical_accuracy: 0.9454
# Epoch 63: val_categorical_accuracy did not improve from 0.90097
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1573 - categorical_accuracy: 0.9454 - val_loss: 0.3462 - val_categorical_accuracy: 0.8994 - lr: 6.8719e-05
# Epoch 64/100
# 926/938 [============================>.] - ETA: 0s - loss: 0.1565 - categorical_accuracy: 0.9474
# Epoch 64: val_categorical_accuracy improved from 0.90097 to 0.90167, saving model to best_model.h5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1566 - categorical_accuracy: 0.9473 - val_loss: 0.3440 - val_categorical_accuracy: 0.9017 - lr: 6.8719e-05
# Epoch 65/100
# 936/938 [============================>.] - ETA: 0s - loss: 0.1541 - categorical_accuracy: 0.9472
# Epoch 65: val_categorical_accuracy did not improve from 0.90167
# 938/938 [==============================] - 6s 7ms/step - loss: 0.1541 - categorical_accuracy: 0.9472 - val_loss: 0.3463 - val_categorical_accuracy: 0.8997 - lr: 6.8719e-05
# Epoch 66/100
# 933/938 [============================>.] - ETA: 0s - loss: 0.1581 - categorical_accuracy: 0.9452
# Epoch 66: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
#
# Epoch 66: val_categorical_accuracy did not improve from 0.90167
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1584 - categorical_accuracy: 0.9451 - val_loss: 0.3465 - val_categorical_accuracy: 0.9009 - lr: 6.8719e-05
# Epoch 67/100
# 928/938 [============================>.] - ETA: 0s - loss: 0.1517 - categorical_accuracy: 0.9486
# Epoch 67: val_categorical_accuracy did not improve from 0.90167
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1521 - categorical_accuracy: 0.9485 - val_loss: 0.3502 - val_categorical_accuracy: 0.9011 - lr: 5.4976e-05
# Epoch 68/100
# 937/938 [============================>.] - ETA: 0s - loss: 0.1486 - categorical_accuracy: 0.9492
# Epoch 68: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
#
# Epoch 68: val_categorical_accuracy did not improve from 0.90167
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1485 - categorical_accuracy: 0.9492 - val_loss: 0.3496 - val_categorical_accuracy: 0.9007 - lr: 5.4976e-05
# Epoch 69/100
# 933/938 [============================>.] - ETA: 0s - loss: 0.1470 - categorical_accuracy: 0.9493
# Epoch 69: val_categorical_accuracy did not improve from 0.90167
# 938/938 [==============================] - 6s 6ms/step - loss: 0.1473 - categorical_accuracy: 0.9492 - val_loss: 0.3475 - val_categorical_accuracy: 0.9012 - lr: 4.3980e-05
# Epoch 69: early stopping

# %%
# to have a more closer to comparison, let's get each prediction
y_pred = np.argmax(model.predict(X_test), axis=1)
# Out:
# 938/938 [==============================] - 2s 2ms/step

# %%
ytest = np.argmax(y_test, axis=1)
confusion_matrix(ytest, y_pred)
# Out:
# array([[2830,    1,   16,    4,    8,   10,   33,   10,   44,    5],
#        [   1, 3290,   13,   13,    4,   17,    6,    3,   19,    5],
#        [  41,   15, 2729,   58,   20,   11,   40,   33,   27,    5],
#        [  12,   19,   75, 2605,    3,  126,    9,   33,  148,   36],
#        [   8,    4,   16,    2, 2602,    9,   55,   21,   22,  182],
#        [  15,    9,   25,  143,    7, 2325,   41,   18,  105,   23],
#        [  29,   10,   18,    2,   38,   35, 2790,    1,   34,    2],
#        [   3,   15,   30,   29,   31,    2,    0, 2889,   31,  103],
#        [  19,   44,   13,  174,   24,  100,   59,   23, 2406,   63],
#        [  26,    6,    4,   46,  156,   12,    5,   98,   52, 2569]])

# %%
print(classification_report(ytest, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      2961
#            1       0.96      0.98      0.97      3371
#            2       0.93      0.92      0.92      2979
#            3       0.85      0.85      0.85      3066
#            4       0.90      0.89      0.90      2921
#            5       0.88      0.86      0.87      2711
#            6       0.92      0.94      0.93      2959
#            7       0.92      0.92      0.92      3133
#            8       0.83      0.82      0.83      2925
#            9       0.86      0.86      0.86      2974
#
#     accuracy                           0.90     30000
#    macro avg       0.90      0.90      0.90     30000
# weighted avg       0.90      0.90      0.90     30000

# %%
# accuracy plot
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()
# loss plot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid()
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
import seaborn as sns
cf_matrix = confusion_matrix(ytest, y_pred)
row_sums = cf_matrix.sum(axis=1)
new_matrix = cf_matrix/ row_sums[:, np.newaxis]
sns.set(rc = {'figure.figsize':(9, 8)})
sns.heatmap(new_matrix, annot=True, fmt='.1%', cmap='Blues')
# Out:
# <Axes: >
